# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(10)
data = pd.DataFrame({
    'value': np.concatenate([np.random.normal(0,100,500), np.random.normal(100,10,500)])
})
q1 = data['value'].quantile(0.25)
q3 = data['value'].quantile(0.75)
IQR = q3-q1
lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR
outliers = data[(data['value'] < lower_bound) | (data['value'] > upper_bound)]
print(outliers)
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(x=data['value'])
plt.title('BOx Plot')
plt.subplot(1,2,2)
sns.violinplot(x=data['value'])
plt.title('violin Plot')
plt.tight_layout()
plt.show()
# Out:
#           value
# 2   -154.540029
# 20  -197.772828
# 21  -174.337230
# 67  -141.855603
# 75   246.765106
# 76  -150.832149
# 82  -185.618548
# 85  -213.171211
# 89  -199.439377
# 99  -195.451212
# 101 -190.745689
# 119 -161.857075
# 123  246.532508
# 159 -297.959677
# 164 -229.510333
# 170 -171.107120
# 180 -142.088052
# 205 -194.129968
# 209 -158.655176
# 216 -154.730539
# 223 -153.306872
# 240 -201.771865
# 242 -144.229888
# 243 -160.885036
# 247 -169.840149
# 289 -239.557201
# 309 -165.860471
# 310  267.991031
# 330 -151.507568
# 339 -198.363650
# 350 -163.558662
# 354 -169.196793
# 371 -138.682253
# 373 -217.660863
# 404 -163.494414
# 412 -320.440134
# 440 -168.044592
# 450 -141.575321
# 467 -155.754247
# 475 -209.779187
# 485 -137.311418
